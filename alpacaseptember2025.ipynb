# %%
import yfinance as yf

import pandas as pd

# Load your SP500.csv
csv_path = "/Users/raghav/Downloads/sp500tickers/SP500.csv"  # update if needed
df = pd.read_csv(csv_path)

# Get tickers as list
tickers = df["Symbol"].dropna().unique().tolist()

print("Total tickers:", len(tickers))
print("Sample:", tickers[:10])  # just to preview
# Out:
# Total tickers: 505
# Sample: ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'AYI', 'ADBE', 'AAP', 'AMD']

# %%
tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ATVI',
#  'AYI',
#  'ADBE',
#  'AAP',
#  'AMD',
#  'AES',
#  'AET',
#  'AMG',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALXN',
#  'ALGN',
#  'ALLE',
#  'AGN',
#  'ADS',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'APC',
#  'ADI',
#  'ANDV',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'APA',
#  'AIV',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ADM',
#  'ARNC',
#  'AJG',
#  'AIZ',
#  'T',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BHGE',
#  'BLL',
#  'BAC',
#  'BAX',
#  'BBT',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'BIIB',
#  'BLK',
#  'HRB',
#  'BA',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BHF',
#  'BMY',
#  'AVGO',
#  'BF.B',
#  'CHRW',
#  'CA',
#  'COG',
#  'CDNS',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CAT',
#  'CBOE',
#  'CBG',
#  'CBS',
#  'CELG',
#  'CNC',
#  'CNP',
#  'CTL',
#  'CERN',
#  'CF',
#  'SCHW',
#  'CHTR',
#  'CHK',
#  'CVX',
#  'CMG',
#  'CB',
#  'CHD',
#  'CI',
#  'XEC',
#  'CINF',
#  'CTAS',
#  'CSCO',
#  'C',
#  'CFG',
#  'CTXS',
#  'CME',
#  'CMS',
#  'KO',
#  'CTSH',
#  'CL',
#  'CMCSA',
#  'CMA',
#  'CAG',
#  'CXO',
#  'COP',
#  'ED',
#  'STZ',
#  'GLW',
#  'COST',
#  'COTY',
#  'CCI',
#  'CSRA',
#  'CSX',
#  'CMI',
#  'CVS',
#  'DHI',
#  'DHR',
#  'DRI',
#  'DVA',
#  'DE',
#  'DAL',
#  'XRAY',
#  'DVN',
#  'DLR',
#  'DFS',
#  'DISCA',
#  'DISCK',
#  'DISH',
#  'DG',
#  'DLTR',
#  'D',
#  'DOV',
#  'DWDP',
#  'DPS',
#  'DTE',
#  'DUK',
#  'DRE',
#  'DXC',
#  'ETFC',
#  'EMN',
#  'ETN',
#  'EBAY',
#  'ECL',
#  'EIX',
#  'EW',
#  'EA',
#  'EMR',
#  'ETR',
#  'EVHC',
#  'EOG',
#  'EQT',
#  'EFX',
#  'EQIX',
#  'EQR',
#  'ESS',
#  'EL',
#  'RE',
#  'ES',
#  'EXC',
#  'EXPE',
#  'EXPD',
#  'ESRX',
#  'EXR',
#  'XOM',
#  'FFIV',
#  'FB',
#  'FAST',
#  'FRT',
#  'FDX',
#  'FIS',
#  'FITB',
#  'FE',
#  'FISV',
#  'FLIR',
#  'FLS',
#  'FLR',
#  'FMC',
#  'FL',
#  'F',
#  'FTV',
#  'FBHS',
#  'BEN',
#  'FCX',
#  'GPS',
#  'GRMN',
#  'IT',
#  'GD',
#  'GE',
#  'GGP',
#  'GIS',
#  'GM',
#  'GPC',
#  'GILD',
#  'GPN',
#  'GS',
#  'GT',
#  'GWW',
#  'HAL',
#  'HBI',
#  'HOG',
#  'HRS',
#  'HIG',
#  'HAS',
#  'HCA',
#  'HCP',
#  'HP',
#  'HSIC',
#  'HES',
#  'HPE',
#  'HLT',
#  'HOLX',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HPQ',
#  'HUM',
#  'HBAN',
#  'HII',
#  'IDXX',
#  'INFO',
#  'ITW',
#  'ILMN',
#  'INCY',
#  'IR',
#  'INTC',
#  'ICE',
#  'IBM',
#  'IP',
#  'IPG',
#  'IFF',
#  'INTU',
#  'ISRG',
#  'IVZ',
#  'IQV',
#  'IRM',
#  'JBHT',
#  'JEC',
#  'SJM',
#  'JNJ',
#  'JCI',
#  'JPM',
#  'JNPR',
#  'KSU',
#  'K',
#  'KEY',
#  'KMB',
#  'KIM',
#  'KMI',
#  'KLAC',
#  'KSS',
#  'KHC',
#  'KR',
#  'LB',
#  'LLL',
#  'LH',
#  'LRCX',
#  'LEG',
#  'LEN',
#  'LUK',
#  'LLY',
#  'LNC',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LYB',
#  'MTB',
#  'MAC',
#  'M',
#  'MRO',
#  'MPC',
#  'MAR',
#  'MMC',
#  'MLM',
#  'MAS',
#  'MA',
#  'MAT',
#  'MKC',
#  'MCD',
#  'MCK',
#  'MDT',
#  'MRK',
#  'MET',
#  'MTD',
#  'MGM',
#  'KORS',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MAA',
#  'MHK',
#  'TAP',
#  'MDLZ',
#  'MON',
#  'MNST',
#  'MCO',
#  'MS',
#  'MSI',
#  'MYL',
#  'NDAQ',
#  'NOV',
#  'NAVI',
#  'NTAP',
#  'NFLX',
#  'NWL',
#  'NFX',
#  'NEM',
#  'NWSA',
#  'NWS',
#  'NEE',
#  'NLSN',
#  'NKE',
#  'NI',
#  'NBL',
#  'JWN',
#  'NSC',
#  'NTRS',
#  'NOC',
#  'NCLH',
#  'NRG',
#  'NUE',
#  'NVDA',
#  'ORLY',
#  'OXY',
#  'OMC',
#  'OKE',
#  'ORCL',
#  'PCAR',
#  'PKG',
#  'PH',
#  'PDCO',
#  'PAYX',
#  'PYPL',
#  'PNR',
#  'PBCT',
#  'PEP',
#  'PKI',
#  'PRGO',
#  'PFE',
#  'PCG',
#  'PM',
#  'PSX',
#  'PNW',
#  'PXD',
#  'PNC',
#  'RL',
#  'PPG',
#  'PPL',
#  'PX',
#  'PCLN',
#  'PFG',
#  'PG',
#  'PGR',
#  'PLD',
#  'PRU',
#  'PEG',
#  'PSA',
#  'PHM',
#  'PVH',
#  'QRVO',
#  'QCOM',
#  'PWR',
#  'DGX',
#  'RRC',
#  'RJF',
#  'RTN',
#  'O',
#  'RHT',
#  'REG',
#  'REGN',
#  'RF',
#  'RSG',
#  'RMD',
#  'RHI',
#  'ROK',
#  'COL',
#  'ROP',
#  'ROST',
#  'RCL',
#  'SPGI',
#  'CRM',
#  'SBAC',
#  'SCG',
#  'SLB',
#  'SNI',
#  'STX',
#  'SEE',
#  'SRE',
#  'SHW',
#  'SIG',
#  'SPG',
#  'SWKS',
#  'SLG',
#  'SNA',
#  'SO',
#  'LUV',
#  'SWK',
#  'SBUX',
#  'STT',
#  'SRCL',
#  'SYK',
#  'STI',
#  'SYMC',
#  'SYF',
#  'SNPS',
#  'SYY',
#  'TROW',
#  'TPR',
#  'TGT',
#  'TEL',
#  'FTI',
#  'TXN',
#  'TXT',
#  'BK',
#  'CLX',
#  'COO',
#  'HSY',
#  'MOS',
#  'TRV',
#  'DIS',
#  'TMO',
#  'TIF',
#  'TWX',
#  'TJX',
#  'TMK',
#  'TSS',
#  'TSCO',
#  'TDG',
#  'TRIP',
#  'FOXA',
#  'FOX',
#  'TSN',
#  'USB',
#  'UDR',
#  'ULTA',
#  'UAA',
#  'UA',
#  'UNP',
#  'UAL',
#  'UNH',
#  'UPS',
#  'URI',
#  'UTX',
#  'UHS',
#  'UNM',
#  'VFC',
#  'VLO',
#  'VAR',
#  'VTR',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VIAB',
#  'V',
#  'VNO',
#  'VMC',
#  'WMT',
#  'WBA',
#  'WM',
#  'WAT',
#  'WEC',
#  'WFC',
#  'HCN',
#  'WDC',
#  'WU',
#  'WRK',
#  'WY',
#  'WHR',
#  'WMB',
#  'WLTW',
#  'WYN',
#  'WYNN',
#  'XEL',
#  'XRX',
#  'XLNX',
#  'XL',
#  'XYL',
#  'YUM',
#  'ZBH',
#  'ZION',
#  'ZTS']

# %%
import yfinance as yf
import pandas as pd

# Download data for all tickers
data = yf.download(tickers, period="1d")["Close"]

# data is a DataFrame with Date as index and tickers as columns
# Select the last row (latest prices)
latest_prices = data.iloc[-1]

# Convert to DataFrame
prices_df = latest_prices.reset_index()
prices_df.columns = ["Ticker", "Price"]

print(prices_df.head())
# Out:
# /var/folders/92/sfk96cdd5y5754wnlxc583zc0000gn/T/ipykernel_6134/1326219286.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, period="1d")["Close"]
# [*****************     35%                       ]  177 of 505 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       2 import pandas as pd
#       4 # Download data for all tickers
# ----> 5 data = yf.download(tickers, period="1d")["Close"]
#       7 # data is a DataFrame with Date as index and tickers as columns
#       8 # Select the last row (latest prices)
#       9 latest_prices = data.iloc[-1]
#
# File /opt/anaconda3/lib/python3.11/site-packages/yfinance/utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File /opt/anaconda3/lib/python3.11/site-packages/yfinance/multi.py:167, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, interval, prepost, proxy, rounding, timeout, session, multi_level_index)
#     160         _download_one_threaded(ticker, period=period, interval=interval,
#     161                                start=start, end=end, prepost=prepost,
#     162                                actions=actions, auto_adjust=auto_adjust,
#     163                                back_adjust=back_adjust, repair=repair, keepna=keepna,
#     164                                progress=(progress and i > 0),
#     165                                rounding=rounding, timeout=timeout)
#     166     while len(shared._DFS) < len(tickers):
# --> 167         _time.sleep(0.01)
#     168 # download synchronously
#     169 else:
#     170     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:

# %%
prices_df
# Out:
#     Ticker       Price
# 0        A  120.150002
# 1      AAL   13.220100
# 2      AAP   56.320000
# 3     AAPL  230.585007
# 4     ABBV  206.210007
# ..     ...         ...
# 500    XYL  141.835007
# 501    YUM  151.990005
# 502    ZBH  104.309998
# 503   ZION   53.139999
# 504    ZTS  155.639999
#
# [505 rows x 2 columns]

# %%
import yfinance as yf
import pandas as pd

# Download data for all tickers
data = yf.download(tickers, period="1d")["Close"]

# Get the last available row (latest prices)
latest_prices = data.iloc[-1]

# Convert to DataFrame
prices_df = latest_prices.reset_index()
prices_df.columns = ["Ticker", "Price"]

# ✅ Filter out tickers with missing prices (NaN)
prices_df = prices_df.dropna().reset_index(drop=True)

print(prices_df.head())
print(f"\nValid tickers: {len(prices_df)} / {len(tickers)}")
# Out:
# /var/folders/92/sfk96cdd5y5754wnlxc583zc0000gn/T/ipykernel_6134/1284052828.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, period="1d")["Close"]
# [*************         28%                       ]  143 of 505 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 import pandas as pd
#       4 # Download data for all tickers
# ----> 5 data = yf.download(tickers, period="1d")["Close"]
#       7 # Get the last available row (latest prices)
#       8 latest_prices = data.iloc[-1]
#
# File /opt/anaconda3/lib/python3.11/site-packages/yfinance/utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File /opt/anaconda3/lib/python3.11/site-packages/yfinance/multi.py:167, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, interval, prepost, proxy, rounding, timeout, session, multi_level_index)
#     160         _download_one_threaded(ticker, period=period, interval=interval,
#     161                                start=start, end=end, prepost=prepost,
#     162                                actions=actions, auto_adjust=auto_adjust,
#     163                                back_adjust=back_adjust, repair=repair, keepna=keepna,
#     164                                progress=(progress and i > 0),
#     165                                rounding=rounding, timeout=timeout)
#     166     while len(shared._DFS) < len(tickers):
# --> 167         _time.sleep(0.01)
#     168 # download synchronously
#     169 else:
#     170     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:
# [**************        29%                       ]  147 of 505 completed

# %%
import yfinance as yf
import pandas as pd

# Download data for all tickers
data = yf.download(tickers, period="1d")["Close"]

# Get the last available row (latest prices)
latest_prices = data.iloc[-1]

# Convert to DataFrame
prices_df = latest_prices.reset_index()
prices_df.columns = ["Ticker", "Price"]

# ✅ Filter out tickers with missing prices (NaN)
prices_df = prices_df.dropna().reset_index(drop=True)

# ✅ Create new list of valid tickers
new_tickers = prices_df["Ticker"].tolist()

print(prices_df.head())
print(f"\nValid tickers: {len(new_tickers)} / {len(tickers)}")
print("\nSample new_tickers:", new_tickers[:10])
# Out:
# /var/folders/92/sfk96cdd5y5754wnlxc583zc0000gn/T/ipykernel_6134/4181065963.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, period="1d")["Close"]
# [*********************100%***********************]  505 of 505 completed
#
# 84 Failed downloads:
# ['ANDV', 'COL', 'SCG', 'PCLN', 'DPS', 'NFX', 'AET', 'TWX', 'GGP', 'EVHC', 'ANSS', 'HCN', 'SNI', 'BF.B', 'WYN', 'CSRA', 'KORS', 'CBG', 'ESRX', 'JNPR', 'HES', 'LUK']: YFPricesMissingError('possibly delisted; no price data found  (period=1d)')
# ['ETFC', 'MRO', 'NBL', 'BRK.B', 'ADS', 'BHGE', 'LLL', 'CERN', 'PKI', 'CTL', 'VAR', 'XEC', 'TMK', 'BBT', 'WRK', 'ANTM', 'SYMC', 'RE', 'TIF', 'JEC', 'ATVI', 'DRE', 'RHT', 'KSU', 'UTX', 'APC', 'ARNC', 'BLL', 'CBS', 'VIAB', 'ABC', 'PDCO', 'PBCT', 'GPS', 'DWDP', 'HCP', 'XLNX', 'CTXS', 'AGN', 'SRCL', 'MYL', 'NLSN', 'HRS', 'DISCK', 'MON', 'DISH', 'PXD', 'CELG', 'DFS', 'TSS', 'CXO', 'XL', 'DISCA', 'FLIR', 'JWN', 'CHK', 'FISV', 'COG', 'ALXN', 'WLTW', 'FBHS', 'RTN']: YFPricesMissingError('possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")')
#   Ticker       Price
# 0      A  119.110001
# 1    AAL   12.800000
# 2    AAP   56.560001
# 3   AAPL  226.009995
# 4   ABBV  209.149994
#
# Valid tickers: 421 / 505
#
# Sample new_tickers: ['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABT', 'ACN', 'ADBE', 'ADI', 'ADM']

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# ================== SETTINGS ==================
LOOKBACK_MONTHS = 12   # for SMA200 & 52w-high
AUTO_ADJUST = False    # be explicit to avoid surprises
# ==============================================

# ===== Helpers =====
def rsi(series, period: int = 14):
    delta = series.diff()
    up = np.where(delta > 0, delta, 0.0)
    down = np.where(delta < 0, -delta, 0.0)
    roll_up = pd.Series(up, index=series.index).ewm(alpha=1/period, adjust=False).mean()
    roll_down = pd.Series(down, index=series.index).ewm(alpha=1/period, adjust=False).mean()
    rs = roll_up / (roll_down.replace(0, np.nan))
    return 100 - (100 / (1 + rs))

def macd(series, fast=12, slow=26, signal=9):
    ema_fast = series.ewm(span=fast, adjust=False).mean()
    ema_slow = series.ewm(span=slow, adjust=False).mean()
    macd_line = ema_fast - ema_slow
    signal_line = macd_line.ewm(span=signal, adjust=False).mean()
    hist = macd_line - signal_line
    return macd_line, signal_line, hist

def zscore(s, cap=3):
    z = (s - s.mean()) / (s.std(ddof=0) + 1e-9)
    return z.clip(-cap, cap) / cap  # scale to [-1,1]

# ===== Download OHLCV for all valid tickers (no batching) =====
data = yf.download(
    new_tickers,
    period=f"{LOOKBACK_MONTHS}mo",
    interval="1d",
    group_by="ticker",
    auto_adjust=AUTO_ADJUST,
    progress=False,
)

# --- Robust extraction of Close & High for any column shape ---
if isinstance(data.columns, pd.MultiIndex):
    lvl0 = data.columns.get_level_values(0)
    lvl1 = data.columns.get_level_values(1)
    if "Close" in lvl0 and "High" in lvl0:
        # Shape: (Field, Ticker)
        close = data["Close"]
        high  = data["High"]
    elif "Close" in lvl1 and "High" in lvl1:
        # Shape: (Ticker, Field)
        close = data.xs("Close", axis=1, level=1)
        high  = data.xs("High",  axis=1, level=1)
    else:
        raise RuntimeError("Could not find Close/High in downloaded data.")
else:
    # Single-ticker case → plain columns
    sym = new_tickers[0] if new_tickers else "TICKER"
    close = data[["Close"]].rename(columns={"Close": sym})
    high  = data[["High"]].rename(columns={"High": sym})

# Drop tickers with no data
close = close.dropna(axis=1, how="all")
high = high[close.columns]

if close.shape[1] == 0:
    raise RuntimeError("No usable tickers after download. Check new_tickers and connectivity.")

# ===== Build Features =====
prices = close.copy()
last = prices.tail(1).T.rename(columns={prices.index[-1]: "Price"})

sma50  = prices.rolling(50, min_periods=40).mean().tail(1).T.rename(columns={prices.index[-1]: "SMA50"})
sma200 = prices.rolling(200, min_periods=150).mean().tail(1).T.rename(columns={prices.index[-1]: "SMA200"})
rsi_14 = prices.apply(rsi, args=(14,)).tail(1).T.rename(columns={prices.index[-1]: "RSI14"})

macd_line, signal_line, hist = macd(prices)
macd_last   = macd_line.tail(1).T.rename(columns={prices.index[-1]: "MACD"})
signal_last = signal_line.tail(1).T.rename(columns={prices.index[-1]: "MACDSignal"})

ret_20 = prices.pct_change(20).tail(1).T.rename(columns={prices.index[-1]: "Ret20"})
ret_60 = prices.pct_change(60).tail(1).T.rename(columns={prices.index[-1]: "Ret60"})

# 52w-high proxy (use full window if <252 rows)
hi_lookback = prices.rolling(252, min_periods=min(60, prices.shape[0])).max()
hi_last = hi_lookback.tail(1).T.rename(columns={prices.index[-1]: "RollingHigh"})
dist_to_high = (last["Price"] / hi_last["RollingHigh"] - 1.0).to_frame(name="DistToHigh")

# Assemble feature table
feat = (
    last.join([sma50, sma200, rsi_14, macd_last, signal_last, ret_20, ret_60, dist_to_high])
        .replace([np.inf, -np.inf], np.nan)
        .dropna()  # ensure all features present
)

# ===== Scoring =====
W = {
    "ret20": 25,
    "ret60": 25,
    "dist_high": 15,
    "price_vs_sma50": 10,
    "sma50_vs_sma200": 10,
    "rsi": 15,
    "macd_signal": 10,
}

score = pd.Series(0.0, index=feat.index)
score += zscore(feat["Ret20"]) * W["ret20"]
score += zscore(feat["Ret60"]) * W["ret60"]
score += ((-feat["DistToHigh"]).clip(0, 1)) * W["dist_high"]
score += (feat["Price"] > feat["SMA50"]).astype(int) * W["price_vs_sma50"]
score += (feat["SMA50"] > feat["SMA200"]).astype(int) * W["sma50_vs_sma200"]
score += ((feat["RSI14"] - 50) / 50).clip(-1, 1) * W["rsi"]
score += (feat["MACD"] > feat["MACDSignal"]).astype(int) * W["macd_signal"]
score += (feat["MACD"] <= feat["MACDSignal"]).astype(int) * (-W["macd_signal"])

rank_df = feat.copy()
rank_df.insert(0, "Score", score.round(2))
rank_df = rank_df.sort_values("Score", ascending=False)

# ===== Output =====
top50 = rank_df.head(50)
bottom50 = rank_df.tail(50)

print("\n===== TOP 50 (Strongest) =====")
print(top50[["Score", "Price"]])

print("\n===== BOTTOM 50 (Weakest) =====")
print(bottom50[["Score", "Price"]])

rank_df.to_csv("sp500_ranked.csv")
print(f"\nSaved full ranking to sp500_ranked.csv with {len(rank_df)} tickers.")
# Out:
# [****************************************179%******************************************]  903 of 505 completed
# 42 Failed downloads:
# ['ATVI', 'JEC', 'DRE', 'KSU', 'APC', 'RHT', 'UTX', 'BLL', 'ARNC', 'VIAB', 'CBS', 'PDCO', 'ABC', 'PBCT', 'AGN', 'XLNX', 'GPS', 'DWDP', 'HCP', 'CTXS', 'SRCL', 'MYL', 'DISCK', 'NLSN', 'HRS', 'DISH', 'MON', 'PXD', 'CELG', 'TSS', 'DFS', 'CXO']: YFPricesMissingError('possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")')
# ['TWX', 'GGP', 'ANSS', 'EVHC', 'HCN', 'SNI', 'BF.B', 'WYN', 'CSRA', 'KORS']: YFPricesMissingError('possibly delisted; no price data found  (period=1d)')
# ===== TOP 50 (Strongest) =====
#         Score        Price
# Ticker
# EBAY    74.52    99.150002
# HBI     67.49     6.240000
# BWA     67.19    42.220001
# KSS     63.12    13.340000
# LNC     62.52    40.880001
# STX     56.70   158.399994
# HCA     55.89   410.179993
# CMI     55.54   396.350006
# EXPE    55.31   205.679993
# PHM     54.73   126.540001
# UAL     51.80    99.839996
# EA      51.51   171.330002
# LEN     50.35   130.320007
# FAST    49.81    49.540001
# GM      49.19    56.770000
# AZO     48.08  4158.100098
# MTD     47.96  1316.880005
# WBA     47.96    12.200000
# HAS     46.37    79.690002
# TSCO    46.06    61.029999
# TMO     45.41   494.809998
# ECL     44.93   285.470001
# RCL     44.48   329.119995
# HPE     43.52    21.040001
# L       43.38    96.699997
# AIZ     43.37   215.399994
# EW      42.08    81.389999
# INTC    41.43    23.540001
# MHK     41.29   124.050003
# DAL     41.04    59.049999
# MA      40.87   592.679993
# GILD    40.82   118.730003
# MNST    40.48    64.389999
# VMC     39.93   286.279999
# AMD     39.58   165.199997
# HP      39.56    17.750000
# NEM     39.28    69.000000
# FOXA    39.18    58.970001
# FOX     38.85    54.009998
# URI     38.70   901.869995
# GPC     38.29   136.990005
# BIIB    37.51   138.990005
# AIG     36.23    82.529999
# TRV     35.99   274.390015
# HLT     35.90   269.899994
# HBAN    35.60    16.799999
# COF     35.21   214.710007
# HD      34.86   401.739990
# CINF    34.82   153.649994
# PNR     34.75   105.040001
#
# ===== BOTTOM 50 (Weakest) =====
#         Score        Price
# Ticker
# FMC      1.99    38.549999
# PCAR     0.53    98.180000
# IR       0.30    79.040001
# WU       0.19     8.300000
# IBM     -0.80   242.550003
# ROK     -1.20   339.619995
# MAA     -1.44   142.360001
# CRM     -1.45   246.449997
# LLY     -1.48   705.440002
# ISRG    -1.85   480.450012
# KHC     -1.85    27.420000
# ESS     -2.77   262.040009
# LYB     -3.61    55.330002
# PWR     -3.95   375.869995
# CNC     -4.47    29.400000
# XRAY    -5.15    14.260000
# WMB     -5.53    57.220001
# CTSH    -5.78    70.489998
# KMI     -6.22    26.570000
# MAT     -6.59    17.700001
# CTAS    -7.11   216.729996
# BHF     -7.89    46.689999
# ACN     -8.93   255.050003
# ETN     -8.99   346.220001
# DE      -9.04   492.720001
# HAL     -9.08    21.100000
# EMR     -9.68   130.889999
# UPS    -10.77    86.940002
# IFF    -10.83    66.110001
# FLS    -12.91    52.150002
# EMN    -13.02    66.620003
# BAX    -13.61    24.270000
# HON    -14.62   217.000000
# TGT    -14.87    98.690002
# CMG    -16.97    43.070000
# TDG    -17.27  1402.160034
# RRC    -20.43    33.080002
# VNO    -20.46    36.680000
# IRM    -21.43    91.290001
# LKQ    -23.72    30.620001
# OKE    -25.42    73.680000
# HRB    -27.59    51.439999
# FLR    -27.97    40.880001
# PRGO   -33.44    23.660000
# VRTX   -33.56   394.359985
# FIS    -33.64    69.760002
# CHTR   -38.07   266.619995
# IT     -39.31   244.199997
# GT     -43.22     8.290000
# UA     -46.99     5.030000
#
# Saved full ranking to sp500_ranked.csv with 201 tickers.

# %%
top50
# Out:
#         Score        Price        SMA50       SMA200      RSI14       MACD  \
# Ticker
# EBAY    74.52    99.150002    82.890800    70.501250  70.612440   5.424152
# HBI     67.49     6.240000     4.801200     6.201250  73.559523   0.508266
# BWA     67.19    42.220001    36.080600    32.372450  79.858222   1.815006
# KSS     63.12    13.340000    10.528600    11.267600  59.824970   0.900528
# LNC     62.52    40.880001    35.621400    34.461800  68.288004   1.587869
# STX     56.70   158.399994   145.942599   107.955600  62.336136   3.486968
# HCA     55.89   410.179993   372.364399   343.789100  76.237919  10.119581
# CMI     55.54   396.350006   352.049599   343.093649  66.741740  14.792834
# EXPE    55.31   205.679993   182.029000   176.860800  66.220369   7.535906
# PHM     54.73   126.540001   113.227800   110.916750  61.625810   4.561604
# UAL     51.80    99.839996    86.582200    87.057900  65.344446   4.057376
# EA      51.51   171.330002   157.287200   148.347800  61.119274   5.428868
# LEN     50.35   130.320007   115.351200   125.036385  65.640529   5.093744
# FAST    49.81    49.540001    45.001000    40.518300  70.121068   1.265657
# GM      49.19    56.770000    52.119400    50.461600  67.390295   1.296930
# AZO     48.08  4158.100098  3796.164395  3542.770798  69.916620  88.358669
# MTD     47.96  1316.880005  1223.067998  1216.844250  63.876806  28.730526
# WBA     47.96    12.200000    11.596800    10.742100  79.862081   0.149697
# HAS     46.37    79.690002    75.301800    64.713450  61.739394   1.550084
# TSCO    46.06    61.029999    56.559400    54.432210  61.951341   1.259618
# TMO     45.41   494.809998   439.746601   484.956700  66.927314  14.639689
# ECL     44.93   285.470001   269.386199   254.625600  70.748946   4.372615
# RCL     44.48   329.119995   314.972601   253.411600  57.660803   0.437475
# HPE     43.52    21.040001    20.082600    19.430850  54.447638   0.334126
# L       43.38    96.699997    91.561400    87.112050  68.229916   1.309667
# AIZ     43.37   215.399994   195.600400   203.808350  68.456549   6.209593
# EW      42.08    81.389999    77.366200    73.529500  64.270516   0.461176
# INTC    41.43    23.540001    21.978200    21.690250  57.019203   0.603670
# MHK     41.29   124.050003   113.207000   117.116850  56.353352   4.059956
# DAL     41.04    59.049999    53.242600    54.984550  61.600149   1.872943
# MA      40.87   592.679993   564.724801   546.756801  67.494822   6.691218
# GILD    40.82   118.730003   112.341200   103.722650  59.740487   2.042732
# MNST    40.48    64.389999    61.697600    56.831400  61.673478   1.008677
# VMC     39.93   286.279999   271.293802   263.872000  56.975024   6.048431
# AMD     39.58   165.199997   153.135799   124.594450  48.814528   5.341105
# HP      39.56    17.750000    16.749200    24.491500  57.706256   0.371602
# NEM     39.28    69.000000    61.674600    49.825350  64.599072   2.290160
# FOXA    39.18    58.970001    55.890200    52.122800  60.808414   0.764820
# FOX     38.85    54.009998    51.248800    48.483225  61.217894   0.646884
# URI     38.70   901.869995   812.160399   736.235648  61.082081  28.616009
# GPC     38.29   136.990005   127.800201   122.369550  62.411472   2.824063
# BIIB    37.51   138.990005   130.547000   138.631150  61.682167   2.149991
# AIG     36.23    82.529999    81.652400    79.268150  61.567592  -0.046714
# TRV     35.99   274.390015   262.660601   256.582000  63.649264   2.119489
# HLT     35.90   269.899994   265.107999   249.475850  53.918614   0.982023
# HBAN    35.60    16.799999    16.561200    16.115850  55.721783   0.022803
# COF     35.21   214.710007   211.708399   191.594399  51.975422   1.023297
# HD      34.86   401.739990   372.857601   383.022400  63.194354   8.842986
# CINF    34.82   153.649994   148.685800   145.048950  56.538574   1.091680
# PNR     34.75   105.040001   103.264400    98.432300  52.156632   0.800595
#
#         MACDSignal     Ret20     Ret60  DistToHigh
# Ticker
# EBAY      5.049018  0.210179  0.378615   -0.016076
# HBI       0.317987  0.319239  0.276074   -0.299663
# BWA       1.493876  0.155762  0.291922    0.000000
# KSS       0.831966  0.084553  0.783422   -0.367773
# LNC       1.416782  0.159387  0.262508   -0.002440
# STX       3.454388  0.036921  0.405003   -0.001890
# HCA       5.544693  0.161095  0.089195   -0.012899
# CMI      14.395755  0.094950  0.249409   -0.025688
# EXPE      6.199290  0.070191  0.293748   -0.019077
# PHM       4.150756  0.060865  0.288464   -0.150966
# UAL       3.184660  0.104058  0.337441   -0.096634
# EA        5.063691  0.114486  0.166383   -0.042903
# LEN       3.982346  0.111376  0.239019   -0.300491
# FAST      1.150486  0.044487  0.218696   -0.007214
# GM        0.997873  0.068511  0.165948   -0.056977
# AZO      78.998958  0.102596  0.086670    0.000000
# MTD      23.642833  0.047471  0.181970   -0.121904
# WBA       0.121787  0.058109  0.092211   -0.056458
# HAS       1.407919  0.037090  0.210542   -0.022329
# TSCO      1.211114  0.023650  0.227968   -0.020071
# TMO      13.174542  0.060209  0.256948   -0.207302
# ECL       2.790755  0.063203  0.093336    0.000000
# RCL      -0.090593 -0.067226  0.370648   -0.067226
# HPE       0.317440  0.013488  0.207807   -0.138411
# L         1.039184  0.050973  0.100364    0.000000
# AIZ       4.386377  0.148126  0.096072   -0.058072
# EW        0.357261  0.058250  0.085345    0.000000
# INTC      0.134981  0.002129  0.174065   -0.140562
# MHK       4.039446  0.063438  0.227003   -0.230698
# DAL       1.391799  0.054841  0.232262   -0.144946
# MA        4.453690  0.054422  0.051634    0.000000
# GILD      1.874984  0.045527  0.105802   -0.014443
# MNST      0.653499  0.087853  0.016256   -0.004638
# VMC       5.911579  0.063803  0.067452   -0.031660
# AMD       7.608951  0.041286  0.497598   -0.104219
# HP        0.228532  0.040446  0.148124   -0.517794
# NEM       2.409164  0.123413  0.286114   -0.004760
# FOXA      0.429010  0.044271  0.071403   -0.015361
# FOX       0.310501  0.040455  0.070989   -0.010443
# URI      29.712324  0.122776  0.288202   -0.032567
# GPC       2.634045  0.017152  0.085413   -0.046429
# BIIB      1.165371  0.061154  0.104761   -0.325880
# AIG      -0.652343  0.037983  0.011149   -0.059166
# TRV       1.235591  0.036451  0.012360   -0.007056
# HLT       0.602542  0.011430  0.102668   -0.031401
# HBAN     -0.032246 -0.001189  0.096606   -0.076923
# COF       0.943330 -0.021644  0.160093   -0.028813
# HD        7.440174  0.067464  0.107607   -0.068688
# CINF      0.974126  0.018089  0.053624   -0.040647
# PNR       0.595824  0.013606  0.085236   -0.038183

# %%
# Just print tickers as a list
print(top50.index.tolist())
print(bottom50.index.tolist())
# Out:
# ['EBAY', 'HBI', 'BWA', 'KSS', 'LNC', 'STX', 'HCA', 'CMI', 'EXPE', 'PHM', 'UAL', 'EA', 'LEN', 'FAST', 'GM', 'AZO', 'MTD', 'WBA', 'HAS', 'TSCO', 'TMO', 'ECL', 'RCL', 'HPE', 'L', 'AIZ', 'EW', 'INTC', 'MHK', 'DAL', 'MA', 'GILD', 'MNST', 'VMC', 'AMD', 'HP', 'NEM', 'FOXA', 'FOX', 'URI', 'GPC', 'BIIB', 'AIG', 'TRV', 'HLT', 'HBAN', 'COF', 'HD', 'CINF', 'PNR']
# ['FMC', 'PCAR', 'IR', 'WU', 'IBM', 'ROK', 'MAA', 'CRM', 'LLY', 'ISRG', 'KHC', 'ESS', 'LYB', 'PWR', 'CNC', 'XRAY', 'WMB', 'CTSH', 'KMI', 'MAT', 'CTAS', 'BHF', 'ACN', 'ETN', 'DE', 'HAL', 'EMR', 'UPS', 'IFF', 'FLS', 'EMN', 'BAX', 'HON', 'TGT', 'CMG', 'TDG', 'RRC', 'VNO', 'IRM', 'LKQ', 'OKE', 'HRB', 'FLR', 'PRGO', 'VRTX', 'FIS', 'CHTR', 'IT', 'GT', 'UA']

# %%
import alpaca_trade_api as tradeapi

# ================= SETTINGS =================
API_KEY = "PKYFT0K4HJKQTTHBPVJD"   
API_SECRET = "PWPgnoRzQGQMxdUtvzeRHwtMMahLztCU9IgeQifO"  
BASE_URL = "https://paper-api.alpaca.markets"

# Example tickers (replace with your own)
tickers = top50.index.tolist()
tickers1 = bottom50.index.tolist()

# =============================================

# Initialize API
api = tradeapi.REST(API_KEY, API_SECRET, BASE_URL, api_version='v2')

# BUY $1000 worth of each stock
for symbol in tickers:
    try:
        api.submit_order(
            symbol=symbol,
            notional=1000,      # $1000 worth of stock
            side='buy',
            type='market',
            time_in_force='day'
        )
        print(f"✅ Order to BUY $1000 of {symbol} placed")
    except Exception as e:
        print(f"❌ Error placing order for {symbol}: {e}")

# SHORT approx $1000 worth of each stock
for symbol in tickers1:
    try:
        # Get latest price
        quote = api.get_latest_trade(symbol)
        price = quote.price

        # Calculate whole share qty to short
        qty = int(1000 // price)   # floor division to ensure integer shares

        if qty > 0:
            api.submit_order(
                symbol=symbol,
                qty=qty,
                side='sell',       # short
                type='market',
                time_in_force='day'
            )
            print(f"✅ Order to SHORT {qty} shares of {symbol} (~$1000)")
        else:
            print(f"⚠️ Skipped {symbol} (price too high for $1000 short)")
    except Exception as e:
        print(f"❌ Error placing SHORT for {symbol}: {e}")
# Out:
# ✅ Order to BUY $1000 of EBAY placed
# ✅ Order to BUY $1000 of HBI placed
# ✅ Order to BUY $1000 of BWA placed
# ✅ Order to BUY $1000 of KSS placed
# ✅ Order to BUY $1000 of LNC placed
# ✅ Order to BUY $1000 of STX placed
# ✅ Order to BUY $1000 of HCA placed
# ✅ Order to BUY $1000 of CMI placed
# ✅ Order to BUY $1000 of EXPE placed
# ✅ Order to BUY $1000 of PHM placed
# ✅ Order to BUY $1000 of UAL placed
# ✅ Order to BUY $1000 of EA placed
# ✅ Order to BUY $1000 of LEN placed
# ✅ Order to BUY $1000 of FAST placed
# ✅ Order to BUY $1000 of GM placed
# ✅ Order to BUY $1000 of AZO placed
# ✅ Order to BUY $1000 of MTD placed
# ✅ Order to BUY $1000 of WBA placed
# ✅ Order to BUY $1000 of HAS placed
# ✅ Order to BUY $1000 of TSCO placed
# ✅ Order to BUY $1000 of TMO placed
# ✅ Order to BUY $1000 of ECL placed
# ✅ Order to BUY $1000 of RCL placed
# ✅ Order to BUY $1000 of HPE placed
# ✅ Order to BUY $1000 of L placed
# ✅ Order to BUY $1000 of AIZ placed
# ✅ Order to BUY $1000 of EW placed
# ✅ Order to BUY $1000 of INTC placed
# ✅ Order to BUY $1000 of MHK placed
# ✅ Order to BUY $1000 of DAL placed
# ✅ Order to BUY $1000 of MA placed
# ✅ Order to BUY $1000 of GILD placed
# ✅ Order to BUY $1000 of MNST placed
# ✅ Order to BUY $1000 of VMC placed
# ✅ Order to BUY $1000 of AMD placed
# ✅ Order to BUY $1000 of HP placed
# ✅ Order to BUY $1000 of NEM placed
# ✅ Order to BUY $1000 of FOXA placed
# ✅ Order to BUY $1000 of FOX placed
# ✅ Order to BUY $1000 of URI placed
# ✅ Order to BUY $1000 of GPC placed
# ✅ Order to BUY $1000 of BIIB placed
# ✅ Order to BUY $1000 of AIG placed
# ✅ Order to BUY $1000 of TRV placed
# ✅ Order to BUY $1000 of HLT placed
# ✅ Order to BUY $1000 of HBAN placed
# ✅ Order to BUY $1000 of COF placed
# ✅ Order to BUY $1000 of HD placed
# ✅ Order to BUY $1000 of CINF placed
# ✅ Order to BUY $1000 of PNR placed
# ✅ Order to SHORT 26 shares of FMC (~$1000)
# ✅ Order to SHORT 10 shares of PCAR (~$1000)
# ✅ Order to SHORT 12 shares of IR (~$1000)
# ✅ Order to SHORT 119 shares of WU (~$1000)
# ✅ Order to SHORT 4 shares of IBM (~$1000)
# ✅ Order to SHORT 2 shares of ROK (~$1000)
# ✅ Order to SHORT 7 shares of MAA (~$1000)
# ✅ Order to SHORT 4 shares of CRM (~$1000)
# ✅ Order to SHORT 1 shares of LLY (~$1000)
# ✅ Order to SHORT 2 shares of ISRG (~$1000)
# ✅ Order to SHORT 36 shares of KHC (~$1000)
# ✅ Order to SHORT 3 shares of ESS (~$1000)
# ✅ Order to SHORT 18 shares of LYB (~$1000)
# ✅ Order to SHORT 2 shares of PWR (~$1000)
# ✅ Order to SHORT 34 shares of CNC (~$1000)
# ✅ Order to SHORT 71 shares of XRAY (~$1000)
# ✅ Order to SHORT 17 shares of WMB (~$1000)
# ✅ Order to SHORT 14 shares of CTSH (~$1000)
# ✅ Order to SHORT 37 shares of KMI (~$1000)
# ✅ Order to SHORT 56 shares of MAT (~$1000)
# ✅ Order to SHORT 4 shares of CTAS (~$1000)
# ✅ Order to SHORT 21 shares of BHF (~$1000)
# ✅ Order to SHORT 3 shares of ACN (~$1000)
# ✅ Order to SHORT 2 shares of ETN (~$1000)
# ✅ Order to SHORT 2 shares of DE (~$1000)
# ✅ Order to SHORT 47 shares of HAL (~$1000)
# ✅ Order to SHORT 7 shares of EMR (~$1000)
# ✅ Order to SHORT 11 shares of UPS (~$1000)
# ✅ Order to SHORT 15 shares of IFF (~$1000)
# ✅ Order to SHORT 19 shares of FLS (~$1000)
# ✅ Order to SHORT 15 shares of EMN (~$1000)
# ✅ Order to SHORT 41 shares of BAX (~$1000)
# ✅ Order to SHORT 4 shares of HON (~$1000)
# ✅ Order to SHORT 10 shares of TGT (~$1000)
# ✅ Order to SHORT 23 shares of CMG (~$1000)
# ⚠️ Skipped TDG (price too high for $1000 short)
# ✅ Order to SHORT 30 shares of RRC (~$1000)
# ✅ Order to SHORT 27 shares of VNO (~$1000)
# ✅ Order to SHORT 11 shares of IRM (~$1000)
# ✅ Order to SHORT 32 shares of LKQ (~$1000)
# ✅ Order to SHORT 13 shares of OKE (~$1000)
# ✅ Order to SHORT 19 shares of HRB (~$1000)
# ✅ Order to SHORT 24 shares of FLR (~$1000)
# ✅ Order to SHORT 42 shares of PRGO (~$1000)
# ✅ Order to SHORT 2 shares of VRTX (~$1000)
# ✅ Order to SHORT 14 shares of FIS (~$1000)
# ✅ Order to SHORT 3 shares of CHTR (~$1000)
# ✅ Order to SHORT 4 shares of IT (~$1000)
# ✅ Order to SHORT 123 shares of GT (~$1000)
# ✅ Order to SHORT 202 shares of UA (~$1000)
